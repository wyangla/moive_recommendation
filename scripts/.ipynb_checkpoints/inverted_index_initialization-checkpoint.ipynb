# %% [markdown]
# # Purpose
# This script is for generating the posting units and tags from the raw data set and feed into the inverted index

# %%
import os
os.chdir('..')  # change current path to the root of project

from inv_index import Index
from data_structure import Post_unit
import pandas as pd
import global_settings as gs
from collections import Counter

os.path.abspath(os.curdir)
# Out:
# 'C:\\desktop\\workspace\\moive_recommendation'

# %% [markdown]
# # Load the raw data
# 1. genome-scores.csv
# 2. genome-tags.csv
# 3. tags.csv

# %%
# genScorePath = os.path.join(gs.datasetPath, 'genome-scores.csv')
# genTagPath = os.path.join(gs.datasetPath, 'genome-tags.csv')
tagPath = os.path.join(gs.datasetPath, 'tags.csv')

# %%
# genScoreDF = pd.read_csv(genScorePath, delimiter = ',')
# genTagDF = pd.read_csv(genTagPath, delimiter = ',')
tagDF = pd.read_csv(tagPath, delimiter = ',')

# %%
tagDF.head()
# Out:
#    userId  movieId            tag   timestamp
# 0      18     4141    Mark Waters  1240597180
# 1      65      208      dark hero  1368150078
# 2      65      353      dark hero  1368150079
# 3      65      521  noir thriller  1368149983
# 4      65      592      dark hero  1368150078

# %%
# not all the movieId are presenting - not all movie have tags
tagDF.movieId.max() - tagDF.movieId.unique().shape
# Out:
# array([111713])

# %%
# not all movie have tag genome scores
# genScoreDF.movieId.max() - genScoreDF.movieId.unique().shape
# Out:
# array([120789])

# %% [markdown]
# # Transfer the raw data into posting unit format
# *userId,movieId,tag,timestamp -> tagText, currentId, nextId, previousId, uPropJson, moiveId, status*
# **Note**: same tags made by different user are regard as different occurances, so that the tf is set

# %%
movieTagCounter = Counter()  # collecting the occurance of tags in terms of one movie

# %%
movieTagCounter
# Out:
# Counter({(4141, 'Mark_Waters'): 2,
#          (208, 'dark_hero'): 9,
#          (353, 'dark_hero'): 34,
#          (521, 'noir_thriller'): 17,
#          (592, 'dark_hero'): 36,
#          (668, 'bollywood'): 8,
#          (898, 'screwball_comedy'): 25,
#          (1248, 'noir_thriller'): 33,
#          (1391, 'mars'): 34,
#          (1617, 'neo-noir'): 39,
#          (1694, 'jesus'): 4,
#          (1783, 'noir_thriller'): 12,
#          (2022, 'jesus'): 42,
#          (2193, 'dragon'): 21,
#          (2353, 'conspiracy_theory'): 20,
#          (2662, 'mars'): 25,
#          (2726, 'noir_thriller'): 29,
#          (2840, 'jesus'): 14,
#          (3052, 'jesus'): 12,
#          (5135, 'bollywood'): 23,
#          (6539, 'treasure'): 34,
#          (6874, 'dark_hero'): 23,
#          (7013, 'noir_thriller'): 29,
#          (7318, 'jesus'): 43,
#          (8529, 'stranded'): 30,
#          (8622, 'conspiracy_theory'): 17,
#          (27803, 'Oscar_(Best_Foreign_Language_Film)'): 6,
#          (27866, 'New_Zealand'): 2,
#          (48082, 'surreal'): 22,
#          (48082, 'unusual'): 6,
#          (51884, 'bollywood'): 16,
#          (58652, 'cute'): 1,
#          (58652, 'emotional'): 1,
#          (58652, 'girls_who_play_boys'): 1,
#          (58652, 'Stephen_Chow'): 5,
#          (106696, 'animation'): 13,
#          (106696, 'beautiful'): 11,
#          (106696, 'characters'): 3,
#          (106696, 'Disney'): 15,
#          (106696, 'feminist'): 9,
#          (106696, 'Ice'): 2,
#          (106696, 'music'): 11,
#          (106696, 'musical'): 12,
#          (106696, 'pacing'): 4,
#          (106696, 'royalty'): 4,
#          (106696, 'siblings'): 8,
#          (106696, 'storyline'): 4,
#          (106696, 'themes'): 4,
#          (106696, 'unnecessary_villain'): 3,
#          (106696, 'voice_acting'): 4,
#          (106696, 'writing'): 5,
#          (778, 'dark_comedy'): 54,
#          (778, 'drugs'): 54,
#          (778, 'Nudity_(Full_Frontal_-_Notable)'): 13,
#          (778, 'Nudity_(Full_Frontal)'): 7,
#          (1288, 'Christopher_Guest'): 18,
#          (1288, 'comedy'): 5,
#          (1288, 'music_business'): 5,
#          (1288, 'rock_and_roll'): 16,
#          (1288, 'satire'): 17,
#          (1288, 'witty'): 10,
#          (2706, 'Nudity_(Topless_-_Notable)'): 15,
#          (2706, 'Nudity_(Topless)'): 8,
#          (2706, 'sexuality'): 15,
#          (2706, 'teen_comedy'): 12,
#          (4718, 'Nudity_(Topless)'): 7,
#          (4718, 'sexuality'): 4,
#          (5283, 'College_Humor'): 5,
#          (5283, 'Nudity_(Topless)'): 5,
#          (5283, 'R'): 3,
#          (5283, 'Ryan_Reynolds'): 6,
#          (5283, 'Teen_movie'): 6,
#          (6188, 'college'): 9,
#          (6188, 'Nudity_(Topless)'): 6,
#          (6188, 'Seann_William_Scott'): 4,
#          (6188, 'Vince_Vaughn'): 9,
#          (6188, 'Will_Ferrell'): 19,
#          (8641, 'Funniest_Movies'): 5,
#          (8641, 'hilarious'): 11,
#          (8641, 'One_of_the_worst_movies_of_all_time'): 2,
#          (8641, 'seen_more_than_once'): 3,
#          (8641, 'Steve_Carell'): 14,
#          (8641, 'Vince_Vaughn'): 6,
#          (8641, 'Will_Ferrell'): 23,
#          (35836, 'comedy'): 25,
#          (35836, 'crude_humor'): 10,
#          (35836, 'Nudity_(Topless_-_Notable)'): 9,
#          (35836, 'Nudity_(Topless)'): 10,
#          (35836, 'Seth_Rogen'): 13,
#          (35836, 'sex'): 19,
#          (35836, 'sex_comedy'): 6,
#          (35836, 'Steve_Carell'): 31,
#          (36529, 'arms_dealer'): 23,
#          (36529, 'dark_comedy'): 25,
#          (36529, 'drugs'): 8,
#          (36529, 'Nicolas_Cage'): 35,
#          (36529, 'Nudity_(Topless)'): 6,
#          (46970, 'Below_R'): 2,
#          (46970, 'Tarantino'): 2,
#          (46970, 'Will_Ferrell'): 19,
#          (52973, 'drugs'): 12,
#          (52973, 'Nudity_(Topless_-_Brief)'): 10,
#          (52973, 'Nudity_(Topless)'): 8,
#          (54503, 'crude_humor'): 10,
#          (54503, 'Highly_quotable'): 7,
#          (54503, 'pornography'): 7,
#          (54503, 'Teen_movie'): 13,
#          (54503, 'virginity'): 11,
#          (59900, 'Adam_Sandler'): 14,
#          (59900, 'Below_R'): 3,
#          (59900, 'exaggerated'): 9,
#          (59900, 'Israeli/Palestinian_conflict'): 5,
#          (59900, 'over_the_top'): 6,
#          (60756, 'comedy'): 6,
#          (60756, 'Seth_Rogen'): 5,
#          (60756, 'will_ferrell'): 15,
#          (68073, '1960s'): 10,
#          (68073, 'Bill_Nighy'): 5,
#          (68073, 'meandering'): 2,
#          (68073, 'Philip_Seymour_Hoffman'): 13,
#          (68073, 'pirate_radio'): 9,
#          (68073, 'rock_and_roll'): 20,
#          (68073, 'soundtrack'): 5,
#          (80693, 'mental_illness'): 15,
#          (80693, 'Zach_Galifianakis'): 14,
#          (104, 'Adam_Sandler'): 19,
#          (104, 'golf'): 10,
#          (104, 'sports'): 7,
#          (1359, 'Arnold_Schwarzenegger'): 4,
#          (1359, 'christmas_movie'): 2,
#          (1359, 'Xmas_theme(?)'): 2,
#          (2335, 'Adam_Sandler'): 13,
#          (2335, 'American_football'): 4,
#          (2335, 'football'): 6,
#          (2335, 'sport:American_football'): 4,
#          (2706, 'high_school'): 15,
#          (2706, 'Teen_movie'): 7,
#          (2706, 'virginity'): 9,
#          (3556, 'great_ending'): 11,
#          (3556, 'high_school'): 20,
#          (3556, 'lyrical'): 7,
#          (3556, 'melancholy'): 14,
#          (3556, 'psychology'): 21,
#          (3556, 'reflective'): 14,
#          (3556, 'suburbia'): 13,
#          (3556, 'suicide'): 20,
#          (3556, 'visually_appealing'): 16,
#          (4247, 'David_Spade'): 3,
#          (4247, "fuck_you_it's_funny"): 3,
#          (4247, 'movie_to_see'): 2,
#          (4732, 'stupid_:)'): 2,
#          (4878, 'alternate_timeline'): 26,
#          (4878, 'cult_classic'): 8,
#          (4878, 'cult_film'): 29,
#          (4878, 'high_school'): 19,
#          (4878, 'mental_illness'): 48,
#          (4878, 'music'): 5,
#          (4878, 'psychology'): 85,
#          (4878, 'sci-fi'): 44,
#          (4878, 'surreal'): 91,
#          (4878, 'thought-provoking'): 75,
#          (4878, 'time_travel'): 105,
#          (5449, 'Adam_Sandler'): 12,
#          (5449, 'Al_Sharpton'): 2,
#          (5449, 'Winona_Ryder'): 6,
#          (8528, 'Ben_Stiller'): 12,
#          (8528, 'comedy'): 6,
#          (8528, 'funny'): 6,
#          (8528, 'Funny_as_hell'): 2,
#          (8528, 'Idiotic'): 6,
#          (8528, 'seen_more_than_once'): 4,
#          (8528, 'sports'): 4,
#          (8528, 'Vince_Vaughn'): 10,
#          (8528, 'wasted_potential'): 2,
#          (8641, 'Ben_Stiller'): 4,
#          (8641, 'Judd_Apatow_movie'): 4,
#          (8641, 'Paul_Rudd'): 5,
#          (8641, 'Seth_Rogen'): 1,
#          (8641, 'Steve_Carrell'): 9,
#          (33880, 'avante_garde'): 8,
#          (33880, 'bittersweet'): 14,
#          (33880, 'deadpan'): 9,
#          (33880, 'FATHERS_AND_SONS'): 5,
#          (33880, 'independent_film'): 9,
#          (33880, 'Indie'): 7,
#          (33880, 'irreverent'): 6,
#          (33880, 'SEXUAL_AWAKENING'): 6,
#          (33880, 'unique'): 12,
#          (33880, 'weird'): 12,
#          (52952, 'coming_of_age'): 16,
#          (52952, 'friendship'): 9,
#          (52952, 'tattoo'): 4,
#          (52952, 'teenager'): 5,
#          (55280, 'delusion'): 11,
#          (55280, 'delusional'): 5,
#          (55280, 'dork_people'): 2,
#          (55280, 'emotional'): 10,
#          (55280, 'family_affair'): 3,
#          (55280, 'mental_illness'): 22,
#          (55280, 'real_doll'): 4,
#          (55280, 'small_town'): 12,
#          (60756, 'brother-brother_relationship'): 3,
#          (60756, 'ending'): 3,
#          (60756, 'Highly_quotable'): 6,
#          (60756, 'let_down'): 2,
#          (60756, 'movie_to_see'): 3,
#          (61132, 'Ben_Stiller'): 24,
#          (61132, 'Hollywood'): 3,
#          (61132, 'irreverent'): 5,
#          (61132, 'Jack_Black'): 15,
#          (61132, 'Robert_Downey_Jr.'): 27,
#          (61132, 'satire'): 23,
#          (61132, 'Tom_Cruise'): 18,
#          (61132, 'Vietnam_War'): 10,
#          (80094, 'handcam-real_style'): 2,
#          (80350, 'funny'): 2,
#          (80350, 'parody'): 4,
#          (80350, 'vampires'): 3,
#          (80489, 'action'): 12,
#          (80489, 'Criminal_=_good_Police_=_bad'): 4,
#          (80489,
#           'one_dimensional_characters_except_for_Affleck._Ending_trite.'): 6,
#          (80489, 'too_much_love_interest'): 7,
#          (80549, 'Emma_Stone'): 41,
#          (80549, 'funny_dialogues'): 6,
#          (80549, 'plot'): 4,
#          (80549, 'sexuality'): 20,
#          (80549, 'typical'): 2,
#          (80549, 'Unreal_reactions'): 5,
#          (80846, 'plot_twist'): 9,
#          (80862, 'documentary'): 4,
#          (80862, 'makes_you_think'): 5,
#          (80862, 'Not_what_was_expected_but_still_good'): 2,
#          (80862, 'social_networking'): 3,
#          (81537, 'drug_use'): 8,
#          (81537, 'road_trip'): 11,
#          (81537, 'Robert_Downey_Jr.'): 19,
#          (81537, 'Zach_Galifianakis'): 22,
#          (81834, 'boring'): 8,
#          (81834, 'camping_trip'): 2,
#          (81834, 'emma_watson'): 1,
#          (4973, 'beautifully_filmed'): 68,
#          (4973, 'quirky'): 65,
#          (4973, 'romance'): 55,
#          (4973, 'stylized'): 41,
#          (4973, 'visually_appealing'): 16,
#          (4973, 'whimsical'): 48,
#          (7158, 'culture_clash'): 10,
#          (7158, 'heartbreaking'): 12,
#          (7158, 'intense'): 3,
#          (7158, 'sad_but_good'): 9,
#          (1270, 'Steven_Spielberg'): 14,
#          (1270, 'time_travel'): 76,
#          (2011, 'sci-fi'): 22,
#          (2011, 'time_travel'): 41,
#          (2012, 'time_travel'): 40,
#          (1966, 'manhattan'): 1,
#          (1966, 'upper_class'): 3,
#          (72, 'whit_stillman_meets_Diner'): 1,
#          (8645, 'actress_too_old'): 1,
#          (8645, 'too_upper_class'): 1,
#          (27727, 'wild_and_fresh'): 2,
#          (40819, 'whit_stillman_meets_diner'): 1,
#          (41573, 'utterly_predictable_ensemble_flick'): 1,
#          (84772, 'Simon_Pegg'): 13,
#          (916, 'Audrey_Hepburn'): 13,
#          (916, 'black_and_white'): 6,
#          (916, 'classic'): 9,
#          (916, 'Gregory_Peck'): 10,
#          (916, 'imdb_top_250'): 3,
#          (916, 'Italy'): 8,
#          (916, 'love_story'): 2,
#          (916, 'National_Film_Registry'): 2,
#          (916, 'need_to_own'): 2,
#          (916, 'romantic_comedy'): 4,
#          (916, 'Rome'): 9,
#          (916, 'royalty'): 4,
#          (916, 'slapstick'): 3,
#          (916, 'zest_for_life'): 3,
#          (4246, 'based_on_a_book'): 6,
#          (4246, 'British'): 13,
#          (4246, 'Hugh_Grant'): 14,
#          (4246, 'Jane_Austen'): 7,
#          (4246, 'romantic_comedy'): 13,
#          (8533, 'chick_flick'): 8,
#          (8533, 'sentimental'): 11,
#          (55872, 'Freddie_Highmore'): 2,
#          (55872, 'inspirational'): 8,
#          (55872, 'love_of_music'): 6,
#          (55872, 'power_of_music'): 8,
#          (55872, 'uplifting_and_compelling'): 4,
#          (34405, 'Firefly'): 24,
#          (34405, 'scifi'): 7,
#          (34405, 'western'): 9,
#          (45186, 'Ethan_Hunt_Should_Stop_Hogging_The_Screen!'): 2,
#          (260, '1970s'): 1,
#          (260, 'fantasy'): 42,
#          (260, 'sci-fi'): 80,
#          (115149, 'Action'): 1,
#          (115149, 'Revenge'): 7,
#          (115149, 'Willem_Dafoe'): 5,
#          (1197, 'must_show'): 1,
#          (1396, 'must_show'): 2,
#          (2011, 'must_show'): 1,
#          (2012, 'must_show'): 1,
#          (2502, 'must_show'): 1,
#          (2762, 'twist'): 2,
#          (2959, 'twist'): 5,
#          (3996, 'overrated'): 5,
#          (6016, 'violent'): 1,
#          (7438, 'violent'): 12,
#          (32, 'post-apocalyptic'): 73,
#          (32, 'psychology'): 38,
#          (32, 'time_travel'): 109,
#          (50, 'organized_crime'): 44,
#          (50, 'twist_ending'): 139,
#          (50, 'twists_&_turns'): 4,
#          (318, 'friendship'): 58,
#          (318, 'masterplan'): 1,
#          (318, 'Morgan_Freeman'): 99,
#          (318, 'prison_escape'): 68,
#          (318, 'redemption'): 4,
#          (318, 'revenge'): 27,
#          (356, 'bittersweet'): 55,
#          (356, 'classic'): 37,
#          (356, 'vietnam_war'): 46,
#          (608, 'crime_gone_awry'): 13,
#          (750, 'black_comedy'): 37,
#          (750, 'British'): 6,
#          (750, 'cold_war'): 24,
#          (750, 'comedy'): 7,
#          (750, 'Peter_Sellers'): 22,
#          (750, 'satire'): 50,
#          (750, 'satirical'): 19,
#          (750, 'Stanley_Kubrick'): 60,
#          (1079, 'British'): 7,
#          (1079, 'John_Cleese'): 18,
#          (1079, 'quirky'): 16,
#          (1136, 'Monty_Python'): 65,
#          (1136, 'parody'): 35,
#          (1136, 'satire'): 26,
#          (1175, 'atmospheric'): 11,
#          (1175, 'post-apocalyptic'): 8,
#          (1175, 'surreal'): 8,
#          (1193, 'psychological'): 19,
#          (1193, 'psychology'): 36,
#          (1201, 'Clint_Eastwood'): 38,
#          (1201, 'Ennio_Morricone'): 26,
#          (1201, 'Italian'): 4,
#          (1201, 'music'): 5,
#          (1201, 'Sergio_Leone'): 26,
#          (1252, 'mystery'): 6,
#          (1252, 'twists_&_turns'): 2,
#          (1625, 'Michael_Douglas'): 24,
#          (1625, 'Mystery'): 33,
#          (1625, 'plot_twist'): 11,
#          (1625, 'psychological'): 43,
#          (1625, 'Sean_Penn'): 10,
#          (1625, 'twist_ending'): 61,
#          (1625, 'unrealistic'): 17,
#          (1653, 'eugenics'): 6,
#          (1653, 'future'): 26,
#          (1653, 'genetic_engineering'): 25,
#          (1653, 'genetics'): 35,
#          (1653, 'powerful_ending'): 29,
#          (1653, 'racism'): 2,
#          (1784, 'funny'): 10,
#          (1784, 'Jack_Nicholson'): 37,
#          (1784, 'obsessive_compulsive_disorder'): 14,
#          (1784, 'psychology'): 18,
#          (1784, 'quirky'): 8,
#          (1784, 'relationships'): 9,
#          (2329, 'Edward_Norton'): 77,
#          (2329, 'Neo-Nazis'): 25,
#          (2329, 'politics'): 12,
#          (2329, 'powerful_ending'): 40,
#          (2329, 'racism'): 52,
#          (2329, 'tense'): 15,
#          (2329, 'thought-provoking'): 51,
#          (2571, 'post-apocalyptic'): 57,
#          (2571, 'sci-fi'): 120,
#          (2571, 'virtual_reality'): 107,
#          (3000, 'adventure'): 14,
#          (3000, 'anime'): 47,
#          (3000, 'fantasy_world'): 20,
#          (3000, 'surreal'): 21,
#          (3359, 'coming_of_age'): 3,
#          (3359, 'coming-of-age'): 2,
#          (3359, 'cycling'): 6,
#          (3363, 'classic'): 2,
#          (3363, 'coming_of_age'): 8,
#          (3363, 'friendship'): 4,
#          (4848, 'BORING!'): 1,
#          (4848, 'Nudity_(Full_Frontal)'): 6,
#          (4848, 'pretentious'): 3,
#          (4973, 'slow_paced'): 1,
#          (4978, 'characters'): 2,
#          (4978, 'romance'): 1,
#          (4993, 'adventure'): 35,
#          (4993, 'characters'): 1,
#          (4993, 'epic'): 14,
#          (4993, 'fantasy_world'): 11,
#          (4993, 'fighting'): 1,
#          (4993, 'photography'): 1,
#          (5282, 'ending'): 1,
#          (5282, 'lawyers'): 1,
#          (5282, 'military_court'): 1,
#          (5291, 'multiple_storylines'): 14,
#          (5291, 'nonlinear'): 14,
#          (6016, 'disturbing'): 18,
#          (6016, 'drama'): 5,
#          (6016, 'multiple_storylines'): 34,
#          (6016, 'realistic'): 3,
#          (6365, 'action_packed'): 1,
#          (6365, 'dystopia'): 17,
#          (6365, 'unrealistic_characters'): 1,
#          (6539, 'cliche'): 1,
#          (6539, 'Johnny_Depp'): 82,
#          (6539, 'magic_realism'): 2,
#          (6539, 'modernism'): 1,
#          (6539, 'photography'): 1,
#          (6539, 'too_long'): 1,
#          (6953, 'multiple_storylines'): 12,
#          (6953, 'psychological'): 17,
#          (6953, 'Sean_Penn'): 18,
#          (7090, 'atmospheric'): 19,
#          (7090, 'colours'): 1,
#          (7090, 'martial_arts'): 33,
#          (7090, 'photography'): 1,
#          (8914, 'dialogue_driven'): 11,
#          (8914, 'mindfuck'): 47,
#          (8914, 'plot_holes'): 5,
#          (8914, 'sci-fi'): 32,
#          (8914, 'time_travel'): 75,
#          (31410, 'Biography'): 8,
#          (31410, 'disturbing'): 12,
#          (31410, 'excellent_performance'): 1,
#          (31410, 'historical'): 10,
#          (31410, 'World_War_II'): 15,
#          (44191, 'comic_book'): 59,
#          (44191, 'dark'): 22,
#          (44191, 'dystopia'): 102,
#          (44191, 'England'): 19,
#          (44191, 'inspirational'): 34,
#          (44191, 'Natalie_Portman'): 44,
#          (44191, 'politics'): 49,
#          (44191, 'thought-provoking'): 83,
#          (44191, 'visually_appealing'): 26,
#          (47044, 'action_packed'): 1,
#          (47044, 'characters'): 1,
#          (47044, 'Miami'): 2,
#          (47044, 'shallow'): 1,
#          (47044, 'unrealistic'): 2,
#          (47044, 'unrealistic_action'): 1,
#          (47044, 'unrealistic_plot'): 2,
#          (48043, 'atmospheric'): 33,
#          (48043, 'death'): 22,
#          (48043, 'emotional'): 9,
#          (48043, 'multiple_storylines'): 14,
#          (48043, 'Music'): 19,
#          (48043, 'nonlinear'): 6,
#          (48043, 'surreal'): 13,
#          (48043, 'thought-provoking'): 23,
#          (48043, 'visually_appealing'): 43,
#          (48774, 'disturbing'): 6,
#          (48774, 'dystopia'): 71,
#          (48774, 'ending'): 2,
#          (48774, 'future'): 25,
#          (48774, 'sci-fi'): 32,
#          (48774, 'violence'): 4,
#          (51662, 'americanized_movie'): 1,
#          (51662, 'based_on_a_comic'): 6,
#          (51662, 'based_on_comic'): 7,
#          (51662, 'blood'): 13,
#          (51662, 'Frank_Miller'): 18,
#          (51662, 'stylized'): 41,
#          (52328, 'atmospheric'): 9,
#          (52328, 'dark'): 15,
#          (52328, 'despair'): 1,
#          (52328, 'ending_twist'): 7,
#          (52328, 'great_soundtrack'): 12,
#          (52328, 'madness'): 8,
#          (52328, 'psychological'): 6,
#          (52328, 'psychology'): 16,
#          (52328, 'slow_paced'): 3,
#          (52328, 'spaceships'): 18,
#          (54372, 'French'): 8,
#          (54372, 'murder_mystery'): 9,
#          (54372, 'twist_ending'): 4,
#          (55442, 'coming_of_age'): 12,
#          (55442, 'Middle_East'): 7,
#          (55442, 'politics'): 17,
#          (55442, 'revolution'): 10,
#          (55442, 'social_commentary'): 11,
#          (55908, 'entirely_dialogue'): 20,
#          (55908, 'Excellent_use_of_dialogue'): 27,
#          (55908, 'immortality'): 22,
#          (55908, 'intellectual'): 31,
#          (55908, 'sci-fi'): 16,
#          (55908, 'thought-provoking'): 39,
#          (55908, 'Underrated'): 10,
#          (55908, 'unique'): 17,
#          (58559, 'Atmospheric'): 32,
#          (58559, 'Batman'): 75,
#          (58559, 'Heath_Ledger'): 88,
#          (58559, 'superhero'): 74,
#          (58559, 'vigilante'): 22,
#          (63082, 'India'): 40,
#          (63082, 'love_story'): 13,
#          (63082, 'Oscar_(Best_Picture)'): 27,
#          (63082, 'photography'): 1,
#          (63082, 'romance'): 19,
#          (63082, 'shallow_plot'): 2,
#          (63082, 'social_commentary'): 31,
#          (63082, 'violence'): 21,
#          (63082, 'visually_appealing'): 7,
#          (64614, 'Clint_Eastwood'): 62,
#          (64614, 'culture_clash'): 32,
#          (64614, 'gangs'): 5,
#          (64614, 'redemption'): 9,
#          (68954, 'emotional'): 5,
#          (68954, 'friendship'): 28,
#          (70286, 'action'): 27,
#          (70286, 'alien_invasion'): 6,
#          (70286, 'aliens'): 74,
#          (70286, 'sci-fi'): 53,
#          (70286, 'social_commentary'): 71,
#          (72167, 'boring_plot'): 1,
#          (72167, 'nonsensical'): 1,
#          (72167, 'stupid'): 1,
#          (72167, 'stupid_characters'): 1,
#          (73321, 'beautiful_scenery'): 9,
#          (73321, 'Bible'): 30,
#          (73321, 'characters'): 1,
#          (73321, 'Christianity'): 34,
#          (73321, 'Denzel_Washington'): 26,
#          (73321, 'dystopic_future'): 19,
#          (73321, 'fight_scenes'): 7,
#          (73321, 'plot_holes'): 9,
#          (79357, 'nonlinear'): 44,
#          (79357, 'Nudity_(Topless)'): 6,
#          (79357, 'sci-fi'): 27,
#          (79357, 'time_travel'): 16,
#          (79357, 'too_long'): 7,
#          (83302, 'cheating'): 4,
#          (83302, 'cold'): 2,
#          (83302, 'husband-wife_relationship'): 5,
#          (83302, 'lack_of_identification'): 3,
#          (83302, 'thought-provoking'): 4,
#          (83302, 'unlikable_characters'): 3,
#          (89118, 'disturbing'): 4,
#          (89118, 'long_revenge'): 3,
#          (89118, 'spanish'): 3,
#          (89118, 'unpredictable'): 1,
#          (90746, 'animation'): 21,
#          (91077, 'coma'): 5,
#          (91077, 'drama'): 3,
#          (91077, 'emotional'): 6,
#          (91077, 'family_bonds'): 7,
#          (91077, 'George_Clooney'): 15,
#          (91077, 'Hawaii'): 10,
#          (96610, 'future'): 9,
#          (96610, 'sci-fi'): 34,
#          (96610, 'time_travel'): 46,
#          (96610, 'violent'): 11,
#          (96610, 'visually_appealing'): 19,
#          (97752, 'adapted_from:book'): 6,
#          (97752, 'atmospheric'): 21,
#          (97752, 'based_on_a_book'): 9,
#          (97752, 'multiple_storylines'): 38,
#          (97752, 'philosophy'): 13,
#          (97752, 'rebellion'): 13,
#          (97752, 'sci-fi'): 17,
#          (97752, 'slow_paced'): 2,
#          (97752, 'social_commentary'): 14,
#          (97752, 'social_criticism'): 7,
#          (97752, 'Tom_Hanks'): 21,
#          (97752, 'visually_appealing'): 25,
#          (99114, 'Leonardo_DiCaprio'): 44,
#          (99114, 'Over_the_top'): 10,
#          (99114, 'Quentin_Tarantino'): 52,
#          (99114, 'Samuel_L._Jackson'): 33,
#          (99114, 'slavery'): 10,
#          (108190, 'based_on_a_book'): 8,
#          (108190, 'dystopia'): 18,
#          (112556, 'based_on_a_book'): 3,
#          (112556, 'marriage'): 8,
#          (112556, 'meticulous'): 7,
#          (112556, 'mindfuck'): 18,
#          (112556, 'Neal_Patrick_Harris'): 6,
#          (112556, 'unpredictable'): 20,
#          (82, 'netflix'): 1,
#          (302, 'netflix'): 1,
#          (571, 'netflix'): 1,
#          (608, 'black_comedy'): 42,
#          (930, 'oppl'): 1,
#          (959, 'netflix'): 1,
#          (974, 'own'): 1,
#          (1123, 'netflix'): 1,
#          (1162, 'netflix'): 1,
#          (1281, 'netflix'): 1,
#          (1412, 'oppl'): 1,
#          (1834, 'netflix'): 2,
#          (1939, 'oppl'): 1,
#          (1942, 'Good_Book_Bad_Movie'): 2,
#          (2065, 'netflix'): 1,
#          (2359, 'Ireland'): 4,
#          (2359, 'Irish'): 4,
#          (2359, 'NOT_British'): 1,
#          (3134, 'netflix'): 1,
#          (3229, 'netflix'): 1,
#          (3533, 'oppl'): 1,
#          (4741, 'netflix'): 1,
#          (4801, 'netflix'): 1,
#          (5225, 'netflix'): 1,
#          (5525, 'netflix'): 1,
#          (5626, 'netflix'): 1,
#          (6042, 'netflix'): 1,
#          (6182, 'oppl'): 1,
#          (6244, 'netflix'): 1,
#          (6647, 'netflix'): 1,
#          (6672, 'netflix'): 1,
#          (6776, 'netflix'): 1,
#          (6828, 'oppl'): 1,
#          (6869, 'netflix'): 1,
#          (7061, 'netflix'): 1,
#          (7082, 'oppl'): 1,
#          (7116, 'oppl'): 1,
#          (7333, 'oppl'): 1,
#          (7479, 'netflix'): 1,
#          (7505, 'netflix'): 1,
#          (7582, 'netflix'): 1,
#          (7583, 'netflix'): 1,
#          (7832, 'netflix'): 1,
#          (7833, 'netflix'): 1,
#          (7835, 'netflix'): 1,
#          (7915, 'netflix'): 1,
#          (8128, 'oppl'): 1,
#          (8207, 'oppl'): 1,
#          (8232, 'netflix'): 1,
#          (8302, 'netflix'): 1,
#          (8335, 'netflix'): 1,
#          (8753, 'netflix'): 1,
#          (8765, 'netflix'): 2,
#          (8786, 'netflix'): 1,
#          (8828, 'netflix'): 1,
#          (8874, 'black_comedy'): 52,
#          (8933, 'netflix'): 1,
#          (8971, 'netflix'): 1,
#          (9000, 'netflix'): 1,
#          (9010, 'netflix'): 1,
#          (25769, 'netflix'): 1,
#          (25828, 'netflix'): 1,
#          (25850, 'KATHARINE_Hepburn'): 1,
#          (25868, 'netflix'): 1,
#          (25886, 'netflix'): 1,
#          (25906, 'netflix'): 1,
#          (25943, 'netflix'): 1,
#          (26116, 'oppl'): 1,
#          (26222, 'netflix'): 1,
#          (26324, 'netflix'): 1,
#          (26325, 'netflix'): 1,
#          (26395, 'netflix'): 1,
#          (26463, 'netflix'): 1,
#          (27002, 'netflix'): 1,
#          (27255, 'netflix'): 1,
#          (27716, 'netflix'): 1,
#          (27866, 'netflix'): 1,
#          (30745, 'netflix'): 1,
#          (31547, 'netflix'): 1,
#          (31903, 'netflix'): 1,
#          (32025, 'netflix'): 1,
#          (32657, 'netflix'): 1,
#          (32853, 'netflix'): 1,
#          (33288, 'netflix'): 1,
#          (38198, 'netflix'): 1,
#          (40010, 'netflix'): 1,
#          (42197, 'black_comedy'): 3,
#          (42422, 'netflix'): 1,
#          (43376, 'netflix'): 1,
#          (44195, 'oppl'): 1,
#          (44633, 'netflix'): 1,
#          (46855, 'oppl'): 1,
#          (46976, 'oppl'): 1,
#          (47152, 'netflix'): 1,
#          (47274, 'oppl'): 1,
#          (47725, 'netflix'): 2,
#          (47940, 'netflix'): 1,
#          (48032, 'netflix'): 1,
#          (48872, 'netflix'): 1,
#          (49225, 'oppl'): 1,
#          (50641, 'netflix'): 2,
#          (50658, 'netflix'): 1,
#          (51255, 'black_comedy'): 37,
#          (51773, 'netflix'): 1,
#          (51991, 'oppl'): 1,
#          (53161, 'not_found'): 1,
#          (53769, 'netflix'): 1,
#          (53883, 'netflix'): 1,
#          (54094, 'netflix'): 1,
#          (54196, 'netflix'): 1,
#          (54745, 'netflix'): 2,
#          (54995, 'netflix'): 1,
#          (55063, 'netflix'): 1,
#          (55156, 'netflix'): 1,
#          (55851, 'netflix'): 1,
#          (55901, 'netflix'): 1,
#          (56671, 'netflix'): 1,
#          (57669, 'black_comedy'): 28,
#          (58191, 'netflix'): 1,
#          (59440, 'anti-abortion'): 3,
#          (59519, 'netflix'): 1,
#          (59549, 'netflix'): 2,
#          (59910, 'netflix'): 1,
#          (60137, 'netflix'): 1,
#          (60147, 'netflix'): 1,
#          (61269, 'netflix'): 1,
#          (63062, '\xa0oppl'): 1,
#          (63698, 'netflix'): 1,
#          (64197, 'netflix'): 2,
#          (64273, 'netflix'): 1,
#          (64278, 'netflix'): 1,
#          (64993, 'netflix'): 1,
#          (65037, 'netflix'): 1,
#          (65235, 'netflix'): 1,
#          (67508, 'netflix'): 1,
#          (67801, 'netflix'): 1,
#          (68472, 'netflix'): 1,
#          (68612, 'netflix'): 1,
#          (68858, 'netflix'): 1,
#          (68967, 'netflix'): 1,
#          (69187, 'netflix'): 1,
#          (69275, 'netflix'): 2,
#          (69529, 'netflix'): 1,
#          (69951, 'new'): 1,
#          (70293, 'france'): 9,
#          (70451, 'netflix'): 1,
#          (70533, 'netflix'): 1,
#          (70687, 'netflix'): 1,
#          (70846, 'netflix'): 1,
#          (71438, 'netflix'): 1,
#          (71468, 'netflix'): 1,
#          (71542, 'oppl'): 1,
#          (71745, 'new'): 1,
#          (72176, 'oppl'): 1,
#          (72395, 'new'): 1,
#          (72554, 'netflix'): 1,
#          (72741, 'oppl'): 1,
#          (73344, 'netflix'): 1,
#          (73587, 'netflix'): 1,
#          (73681, 'netflix'): 1,
#          (74504, 'netflix'): 1,
#          (74677, 'netflix'): 1,
#          (75813, 'netflix'): 2,
#          (76079, 'netflix'): 1,
#          (76091, 'netflix'): 1,
#          (77154, 'netflix'): 1,
#          (77307, 'netflix'): 1,
#          (77330, 'oppl'): 1,
#          (77359, 'netflix'): 1,
#          (77421, 'oppl'): 1,
#          (77658, 'netflix'): 2,
#          (77833, 'netflix'): 1,
#          (77854, 'oppl'): 1,
#          (78103, 'netflix'): 1,
#          (78574, 'netflix'): 1,
#          (78746, 'netflix'): 1,
#          (79091, 'oppl'): 1,
#          (79293, 'oppl'): 1,
#          (79357, 'netflix'): 1,
#          (80185, 'netflix'): 1,
#          (80553, 'netflix'): 1,
#          (80584, 'oppl'): 1,
#          (80586, 'oppl'): 1,
#          (80939, 'oppl'): 1,
#          (81383, 'netflix'): 1,
#          (81456, 'netflix'): 1,
#          (81639, 'oppl'): 1,
#          (81804, 'oppl'): 1,
#          (82463, 'netflix'): 1,
#          (83270, 'feminism'): 2,
#          (83270, 'feminist'): 2,
#          (83531, 'netflix'): 1,
#          (84187, 'netflix'): 1,
#          (85179, 'netflix'): 2,
#          (85438, 'netflix'): 1,
#          (86487, 'oppl'): 1,
#          (88267, 'oppl'): 1,
#          (89039, 'netflix'): 1,
#          (90866, 'oppl'): 1,
#          (91077, 'netflix'): 1,
#          (93892, 'netflix'): 1,
#          (93939, 'netflix'): 1,
#          (340, 'Kevin_Pederast'): 1,
#          (1175, 'This_Would_Have_Been_Funnier_If_It_Was_A_Horror_Film'): 1,
#          (1208, "'Oh_The_Whore-ror!'"): 1,
#          (1247, "'Wow_Mrs._Robinson_Your_Porridge_Is_Just_Right!'"): 1,
#          (1345,
#           "'Carrie_I_Don't_Wanna_Rain_On_Your_Parade_But_That's_Not_Fruit_Punch'"): 1,
#          (1372,
#           "'Oh_Spock!_Oh_Jim!_Oh_Bones!'_WTF!?_Et_Tu_Herr_Doktor?_Heil!"): 1,
#          (1502, "Of_Course_It's_Rigid!_The_Dude's_In_Full_Rigor!"): 1,
#          (1508,
#           "All_Of_A_Sudden_You_Feel_Guilty_About_Bangin'_Yer_Own_Daughter_Why_Stop_Now?"): 1,
#          (1554, 'Ewe_Mean_Sausage_McHoody_With_Eggs'): 1,
#          (1674, "'I_Guess_Repression_Does_Have_It's_Moments_After_All'"): 1,
#          (2076,
#           "'It's_Not_Where_Your_Dreams_Take_You_But_Who_You_Take_In_Your_Dreams'_hahaha!"): 1,
#          (2087, "'And_Just_What_Do_You_Think_You're_Doing_Mr._Smeee?'"): 1,
#          (2202, "You_Mean_It's_Over_Inflated!"): 1,
#          (2268, "'That's_All_An_Inmate_Wants...Simple_Pleasures'"): 1,
#          (2275, 'Guy_Pierce_With_Dweeb_Focals'): 1,
#          (2359, "'Didn't_This_Already_Happen_To_Bernie?'"): 1,
#          (2745, 'Was_The_Mission_About_Finding_A_Position?'): 1,
#          (3030,
#           "You_Only_Got_2_Bullets._I_Have_A_Sword._You_Will_Miss._I_Won't."): 1,
#          (3101,
#           "'Hey_Dan_Do_You_Mind_Having_Rabbit_Stew_For_A_Pick-Me-Up?'"): 1,
#          (3148, 'the_book_was_bettah'): 1,
#          (3192, 'Great_Anti-Abortion_Film'): 1,
#          (3471,
#           "'Stop_Banging_The_Doorbell_I'm_Landscaping_My_Kitchen_Sink!'"): 1,
#          (3660, "'I_Can't_Get_That_Theme_Song_Out_Of_My_Head'"): 1,
#          (3709, "Perfect_Use_Of_Johnny_&_Santo's_1_Hit_Wonder"): 1,
#          (3755,
#           "'On_A_Steel_Horse_I_Ride_I'm_Wanted_(waaaanteeddd)_Dead_Or_Alive'"): 1,
#          (4719, 'The_5-Second_Rule_Never_Applies_Near_Animals_Or_In_Zoos'): 1,
#          (4975, 'Re-Fried_For_U.S.'): 1,
#          (4978,
#           'The_Mother_Of_Connect-The-Dots__Flix_(Grand_Canyon/Crash/ETC)'): 2,
#          (5319, "'Don't_Watch_'Criminal'_Totally_Butchered'"): 1,
#          (5807,
#           "'Yeah_The_Test_Audience_Thought_That_Was_A_Better_Title...More_Upbeat'"): 1,
#          (5956,
#           "'Know_Why_I_Like_Butchering_Pigs?_It's_Like_Killing_Cops_But_Without_The_Jail_Time'"): 1,
#          (5992, 'even_crazy_people_like_to_be_asked_out'): 1,
#          (5995, "'The_What?!'"): 1,
#          (6286,
#           'Sometimes_Marriage_Makes_You_Wanna_Forget_Why_The_Hell_You_Said_YES'): 2,
#          (6294,
#           'With_A_Name_Like_Chew_Yer_Fat_A_Crossover_Is_Not_Possible'): 1,
#          (6301,
#           'Even_Dweebs_Go_Psycho_If_You_Keep_Making_Fun_Of_Their_Glasses'): 1,
#          (6511, '\'H_Christ!"'): 1,
#          (6656,
#           "'Why_Is_Everyone_Running_Around_With_Puppets_Up_Their_A**?!'"): 1,
#          (6708, "'Alison_Lohman_Stole_The_Whole_Damn_Film'"): 1,
#          (6713, 'Animated_Woody_Allen_Film...If_He_Made_One'): 2,
#          (6914,
#           "'I_Have_Never_Had_Any_Foreign_Relations_With_That_Woman_Hillary_Lewinsky'"): 1,
#          (6963, "...'Livin'_In_An_Amish_Paradise'"): 1,
#          (7143, "'The_Ninja_Assault_Gets_A_3peat'"): 1,
#          (7442, 'Just_Great._Now_Every1_Knows_Ewan_Is_"Hooded"'): 1,
#          (7828,
#           "'And_When_The_Germans_Came_Over_The_Ridge_They_Suddenly_Went_Blind!'"): 1,
#          (7925, "'Is_That_What_He_Called_It?'"): 1,
#          (8295, "Wasn't_That_Human_Played_By_Ice-T?"): 1,
#          (8367,
#           "If_The_Director_Doesn't_Care_2_Flesh_Out_A_Film_Why_The_Hell_Should_I_Care_What_Happens_2_The_Characters?"): 1,
#          (8369, 'More_Like_Plothunters_Or_Why_Did_I_Watch_This?'): 1,
#          (8505, "'Is_That_What_She_Calls_It?'"): 1,
#          (8720, 'Loved_The_Mouse_Wake-Up'): 1,
#          (8862, '9ine_Queens_Was_A_Better_Title...&_Film'): 1,
#          (8919,
#           'Hmmm_I_Wonder_How_Many_Counselors_Do_Their_Jobs_Like_That!'): 1,
#          (26413,
#           "'That's_Where_You_Enter_From_Behind_After_A_Running_Jump'"): 1,
#          (26464, 'Just_Another_F***ing_A-Hole!'): 1,
#          (26688, 'He_Loses_All_Credibility_When_He_Runs_LOL!'): 2,
#          (26696,
#           'Cynthia(Deborah_Rennard)_Was_The_Only_Performer_To_Watch_In_This_Drek!_More_Like_L_I_O_N_A_S_S!'): 1,
#          (26840, 'Takeshi_Definitely_Beat_This_Genre_To_The_Ground'): 1,
#          (27432,
#           'Fight_For_Your_Dreams_Because_People_Are_Dying_For_Theirs'): 1,
#          (27664, 'A_Married_Couples_Excuse_To_Shag_On_Film'): 1,
#          (27689, 'Merde!'): 1,
#          (27846,
#           "Like_Michael_Crichton_Sez_Help_Stop_Gene_Patenting!_Or_Sooner_Than_Later_You_Won't_Even_Own_Your_Cells!"): 1,
#          (27904, "Zoom_In_&_Slo-Mo_The_Porking_Scene_With_Ridin'_Winona"): 1,
#          (31410,
#           "'You_Know_What_They_Say_About_Short_Men_With_Little_Toes'"): 1,
#          (31617, "'This_Is_My_Gun._I_Love_To_Touch_My_Gun._Touch_My_Gun.'"): 1,
#          (32582, 'A_Deadhead_With_A_Parrot_Fetish'): 1,
#          (32600,
#           'Tailoring_Would_Be_Back_In_Style_If_More_Women_Appreciated_Clothes_In_THAT_Way!'): 1,
#          (33358, 'Mrs._Jones_Distracted_Me_The_Whole_Movie'): 1,
#          (33592, 'Being_Prostituted_By_Your_Husband_Is_Never_Romantic!'): 1,
#          (33649,
#           "Wonderful_Asian_Film_That_Shows_Why_We_Shouldn't_Hide_Who_We_Really_Are"): 2,
#          (33817,
#           'Emily_Blunt_Is_Sooo_Very...___She_Was_Amazing_In_Irresistable'): 1,
#          (33823, 'Please_Stop_Re-Frying_Books_That_Suck_Donkey_D***!'): 1,
#          (34271, 'We_All_Gotta_Have_A_Dream'): 1,
#          (34323,
#           'Do_People_Really_Have_2_Pay_10_Bucks_To_See_How_Cruel_We_Are_To_Each_Other?_Try_Getting_Married!'): 2,
#          (34338, 'When_It_Comes_Down_To_It_Toilet_Humor_Always_S(m)ells'): 1,
#          (34437,
#           "It's_The_Journey_Not_The_Destination_That_We_Should_Enjoy"): 1,
#          (34542, 'Never_Ever_Discuss_Your_Lack_Of_Game_To_Wild_Bears!'): 1,
#          (35957, 'Never_Trust_Euro-Looking_A-Holes_@_The_Airport.Com'): 1,
#          (36517,
#           "'There's_A_Lotta_These_At_Used_Book_Stores...Hmmm_I_Wonder_Why_It_Sucks_That_Bad'"): 1,
#          (36529, "I_Don't_Think_Arms_Dealers_Look_Anything_Like_Nick_Cage"): 1,
#          (36535, 'Where_Can_I_Learn_To_Speak_English_Like_That?'): 1,
#          (36537, 'Teen_Induced_Angst_Overdose'): 1,
#          (37380, 'Half-Assed_Productions'): 3,
#          (37386,
#           "How_Come_Charlize_Can_Play_A_Serial_Killer_But_She_Can't_Show_More_Skin_Oh_Come_On!"): 1,
#          (37729, 'Tim_Burton_Hits_Another_One_Out_Of_The_Cemetery'): 1,
#          (37731,
#           "They_Made_This_Already_And_It_Was_Titled:_Football_Factory_It's_Way_Better_Than_This_Re-Hash"): 2,
#          (37853,
#           'Millions_Of_Dollars_In_Drugs_Or_One_Hot_Girlfriend...You_Choose'): 1,
#          (37855, 'Brighton_Beach_Memoirs_&_Juliana_Moore'): 1,
#          (37857, 'No_Wonder_Carneys_Love_The_Life'): 1,
#          (38188,
#           "What's_Really_Scary_Is_That_There's_People_Like_That_In_Real_Life!"): 1,
#          (38992,
#           "Isn't_Renee_Russo_Like_100_Years_Old?_Matt!_What_Were_You_Thinking?"): 1,
#          (39183, "Cow_Pokin'_In_Them_Thar_Hills"): 1,
#          (39414, 'Steve_Martin_Is_Scraping_The_Bottom_HARD!'): 2,
#          (39427,
#           'I_Just_Kept_Hearing_Massive_Attack_After_The_Car_Accident'): 1,
#          (40414,
#           'But_What_Did_They_Do_After_New_Years:_Resolve_To_Kill_ALL_My_Enemies'): 2,
#          (41285,
#           "It_Just_Goes_To_Show_Ya_Once_The_Ring_Goes_On_It's_Just_Leftovers"): 1,
#          (41571,
#           'Years_Of_Degredation_And_Humiliation_And_They_Sell_Your_"Mizuage"_To_The_Creepiest_Keymaster'): 1,
#          (41617,
#           'Even_Princesses_Want_To_Have_Pig_Sex_Now_&_Again...&_Again'): 1,
#          (41997, "Stop_Killing_Each_Other_You're_Neighbors!"): 1,
#          (42004, "It's_Not_Just_A_Phase_It's_Really_A_Way_Of_Life"): 1,
#          (42018,
#           "When_You're_Stressed_Out_Nudity_Works_Wonders_For_Your_Nerves"): 1,
#          (42418,
#           'No_Matter_What_Century_It_Is_Jungle_Fever_Is_Very_Contagious!'): 1,
#          (42718,
#           'Parkour:_Getting_Around_Obstacles_A_Great_Complement_To_Being_Alive'): 3,
#          (42721, "I_Guess_Nude_Terminators_Can't_Kill_A_Really_Bad_Film"): 1,
#          (42723,
#           "Oh_No_This_Film_Doesn't_Promote_Murder_&_Suffering_It_Just_Encourages_It!"): 2,
#          (42725, 'Nick_Swardson_Should_Have_Been_Lead_His_Timing_Was_Sic!'): 2,
#          (42728,
#           "The_Whole_Tromeo_&_Juliet_Threw_Me_Off_But_Thank_Gawd_They_Didn't_Talk_Like_Bill_The_Spear_Shaker"): 1,
#          (42734, 'What_If_The_Big_Bad_Wolf_&_Grandma_Were_Swapping_Spit?'): 1,
#          (43556, "An_Orifice_&_A_Gentle_Hand_Refried_For_'06"): 1,
#          (43928,
#           'Read_All_The_Negative_Reviews_&_Save_2_Hours_Of_Your_Life!'): 1,
#          (44511,
#           "'Lemme_Get_This_Straight._You_Have_No_Idea_Who_You_Are_But_You_Wanna_Be_Famous?'"): 1,
#          (44759,
#           'If_I_See_One_More_Roast_Beef_Sandwich_You_Will_Smell_My_Reaction'): 1,
#          (45062,
#           'Obviously_Hillary_Had_A_Different_Meaning_For_"Secret_Service"'): 1,
#          (45431, "'Priceline_Negotiator!'"): 1,
#          (45442, 'The_Power_Of_The_P'): 1,
#          (45730, 'Believe_In_Your_Ability_To_See_Stoopid_Plotlines'): 2,
#          (45732, 'Not_Even_Uma_Could_Save_This_Dizaster!_Wanda_Yikes!'): 2,
#          (46322,
#           "It's_Not_Size_Of_Your_Stick_But_Why_You_Keep_On_Swingin'_It!"): 1,
#          (46530, "'So_How_Did_Lois_Survive_Date_Nite?'"): 1,
#          (46967, 'A_Comedy_Version_Of_Matchpoint'): 2,
#          (48043,
#           'You_Would_Do_Anything_In_The_Universe_To_Get_Rachael_Weisz_Back_As_Well'): 1,
#          (48304,
#           'Or_How_The_Last_Of_The_Mohican_Killed_The_Predator_Escaping_From_The_Thunderdome'): 1,
#          (48385, "'I_Want_To_Meke_Romance_Explosion_On_Her_Stomatch!'"): 1,
#          (48412,
#           'Kevin_Cockner_&_Asstin_Goocher_Guarding_Each_Others_Happy_Holes'): 1,
#          (48516, "You_Know_It's_Bad_If_It's_Been_Reheated...Again"): 1,
#          (48520,
#           'No_Amount_Of_Silly_Cone_Can_Save_A_Steaming_Pile_Of_Shitzu_Like_This'): 1,
#          (48698, 'my_child_let_me_show_you_how_firm_my_faith_is'): 1,
#          (48744, "'Double_Fudge_Bus'"): 1,
#          (49265, 'Rwanda_Genocide'): 1,
#          (49265, 'Rwandan_Genocide'): 1,
#          (49272, 'Bond_Would_Never_Ever_Be_Caught_Driving_A_Frikkin_FORD'): 1,
#          (49278, 'Oh_The_Things_I_Could_Do_If_Snow_White_Were_A_Console'): 2,
#          (49314, 'What_Happens_To_Batman_When_He_Loses_The_Wayne_Fortune'): 2,
#          (49347, "'There's_Shit_In_The_Meat!'"): 1,
#          (49961, "'I_Had_No_Idea_That_You_Were_A_F******_Vampire!'"): 1,
#          (50068, "It's_Biased_When_Watanabe_Uses_A_45_And_Kills_Himself"): 1,
#          (50442, 'Just_In_Timber_Cake_Must_Die!'): 1,
#          (50872, "Pixar's_Formula_Starting_To_Get_Stale"): 3,
#          (51037, "'It's_Just_Hostel_3_With_Better_Actors'"): 1,
#          (51255, 'It_Just_Keeps_Getting_Better'): 1,
#          (51412, "What's_Up_With_The_Da_Vinci_Hair_Do"): 3,
#          (51418, 'Not_Another_Mingella_Stretcher!_We_Hates_Them!'): 1,
#          (51709,
#           'After_The_Reveal_The_Story_Went_Back_Down_And_Never_Came_Up_Again'): 2,
#          (51935,
#           "It's_1_Part_Bad_Memories__1_Part_Double_Cross_Add__A_Twist_Of_Slime_&_Lots_Of_Good_Vibrations!"): 1,
#          (52328, "'Please_Tell_Me_We_Brought_The_Lighter...Please'"): 2,
#          (52456,
#           "'Don't_Look_Into_Berry's_Headlights_She'll_Turn_You_Into_Wood'"): 1,
#          (52458, 'Rear_Pwnage'): 1,
#          (52460,
#           'Karl_Urban_Needs_To_Pick_Better_Projects_&_He_Needs_2_Pick-Up_His_Sword'): 1,
#          (52604,
#           'Lecter_Remarries_&_Kills_His_Insulting_Wife_&_Butts_Heds_With_Hotshot_D.A.'): 1,
#          (52717, "'I'll_Give_You_10_Seconds_Head_Start...10!'"): 1,
#          (52867, "'Saving_Silverman_Part_Deux'"): 1,
#          (53123,
#           "'Take_This_Sinking_Boat_&_Point_It_Home_You_Hoover_Fixer_Sucker_Guuuyyy!'"): 1,
#          (53318, "'Why_Yes_I_Would_So_Love_To_Sketch_Nudes_In_Costco!'"): 1,
#          (53464,
#           "'What_I_Really_Wanna_Know_Is...Does_Alba_Get_Sooper_Nekkid?'"): 1,
#          (53550,
#           "'And_So_The_Bear_And_Little_Deiter_Went_Off_Into_The_Mountains_&_Lived_Like_Homosexual_Bears'"): 1,
#          (53894, "'Now_If_Only_Dubya_Could_Wash_Me_Whites"): 1,
#          (54004, 'Chuck_&_Buck...'): 1,
#          (54270, "'More_Like_Skankwalkers'"): 2,
#          (54276,
#           'Mostly_Martha_Will_Always_Be_The_Best._Aron_Eckhart?_Ninja_Pleaze!'): 1,
#          (54503, 'Super_De-Formed'): 1,
#          (54736, "'Don't_Cry_Jen_I_Promise_We'll_Kill_Them_All'"): 2,
#          (54775, 'The_Director_Should_Be_Be_Shot...In_The_Mouth!'): 1,
#          (54999, "'Why_Is_My_Arm_Wet?_Oh_It's_Just_A_Crushed_Baby'"): 1,
#          (55080, "'STFU!'"): 1,
#          (55272,
#           "'The_Other_Movie_Did_It's_Job...This_Must_Be_The_Wrong_Movie'"): 1,
#          (55276, "'I_Love_You_Anna!'"): 2,
#          (55282, '30_Daze_Of_Shite'): 2,
#          (55284,
#           "'Show_Me_The_Money!_I_Can't_Hear_You_Haji_Scream_Louder!'"): 1,
#          (55391,
#           'A_Bad_Copy_Of_Departed_Which_Was_A_Re-Hash_Of_Infernal_Affairs'): 1,
#          (55820, "'Heads_Or_Tails...Call_It'"): 1,
#          (55830, 'I_felt_sweded'): 1,
#          (55995, "'I_Will_Give_My_Kingdom_For_A_Great_Piece_Of_TWAT!'"): 2,
#          (56001,
#           "'I_Don't_Care_If_You_Have_Cholera_It's_Still_Heads_Or_Tails...Call_It'"): 1,
#          (56286, "'Cate_Dylan_Hmmm...'"): 1,
#          (56757, "'Oh_Edward!__A_Mr._Todd_Would_Like_You_To_Cut_His_Hair'"): 1,
#          (56775, "'It_Should_Have_Been_Kept_A_Secret'"): 1,
#          (56801, "'AKA:_I_Will_Never_Get_Those_2_Hours_Back...Ever'"): 3,
#          (57368, 'blair_gojira_project'): 1,
#          (57951,
#           "we_can_do_this_easy_or_we_can_do_this_reeal_easy_it's_called_magic_hour"): 1,
#          (58103, 'brain_bang'): 1,
#          (59731, "that's_what_he_keeps_asking_for"): 1,
#          (60037,
#           "of_course_you_keep_seeing_dead_people...they're_all_dying!"): 1,
#          (60333, 'not_another_herzog_schwarzenneger_egomentary'): 1,
#          (60760, "...that_it's_finally_over"): 1,
#          (60937,
#           "it's_too_bad_Brendan_can't_shake_the_Encino_Man_syndrome"): 1,
#          (61705,
#           "didja_know_there's_a_black_police_ociffer_on_our_block?_oh_man_there_goes_the_neighborhood"): 2,
#          (61705, '\xa0'): 1,
#          (63033, "'stop_wanking"): 1,
#          (63033, "or_you'll_go...too_late'"): 1,
#          (64497, 'all_your_vagine_are_belong_to_us!'): 1,
#          (64575, "P.S.H_as_a_priest?_oh_you_know_he's_guilty!"): 1,
#          (64839, "mickey_'the_stretch'_rourke"): 1,
#          (64957, 'you_mean_he_gets_to_go_back_inside_the...oh_lucky'): 1,
#          (64983,
#           "no_matter_what_role_it_is_i_will_not_change_my_persona_everybody_worships_'the_cruise'"): 2,
#          (67197, 'shame_on_them!'): 1,
#          (68554, 'angles_and_deadlines'): 1,
#          (68650, 'crash_re-hashed'): 1,
#          (68791, 'good_first_try_for_MCG'): 1,
#          (68791,
#           'should_have_been_longer_to_really_flesh_out_the_feeling_of_bleakness_and_give_a_sense_of_a_last_hope_more_action_more_global_feel'): 1,
#          (69526, 'better_method_AI'): 1,
#          (69526, 'needed_more_autobots'): 2,
#          (69526, 'stop_using_useless_characters_for_filler'): 4,
#          (69529,
#           "we_are_all_connected._it's_not_my_life_or_your_life_it's_all_life._stop_being_afraid_and_hating_the_unknown._smile_and_make_eye_contact."): 4,
#          (69640,
#           "melvin_pervo_didn't_commit_suicide_he_just_offed_hiself_'cleaning'_his_barrel"): 1,
#          (71838, '"Tonite'): 1,
#          (71838, 'Act_From'): 1,
#          (71838, 'Hell!"'): 1,
#          (71838, 'We'): 1,
#          ...})

# %%
for record in tagDF.values:
    movieId = record[1]
    tag = str(record[2]).replace(' ', '_')  # replace the space with '_'
    movieTagCounter[(movieId, tag)] += 1

# %%
flatPUnitList = []  # for collecting the flatten posting units

# %%
# tagText, currentId, nextId, previousId, uPropJson, moiveId, status
for movieTagPair in movieTagCounter:
    flatPUnitList.append("%s -1 -1 -1 {'tf':%d} %d 1"%(movieTagPair[1], movieTagCounter[movieTagPair], movieTagPair[0]))

# %% [markdown]
# # Feed the flatten posting units in to inverted index

# %%
idx = Index()

# %%
flatPUnitList[0]
# Out:
# "Mark Waters -1 -1 -1 {'tf':2} 4141 1"

# %%
Post_unit.deflatten(flatPUnitList[0])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-61-8da4f5bfc8d1> in <module>()
# ----> 1 Post_unit.deflatten(flatPUnitList[0])
#
# ..\data_structure\Post_unit.py in deflatten(cls, flatUnit)
#
# ValueError: invalid literal for int() with base 10: 'Waters'

# %%
for flatPUnit in flatPUnitList:
    Post_unit.deflatten(flatPunit)
